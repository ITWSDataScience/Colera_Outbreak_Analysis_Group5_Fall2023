# %%
import pandas as pd

# %%
file_path = 'gdp_data.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#   Country Name Country Code  \
# 0     Botswana          BWA
# 1     Botswana          BWA
# 2     Botswana          BWA
# 3     Botswana          BWA
# 4     Botswana          BWA
#
#                                          Series Name        Series Code  \
# 0   Adjusted net national income (constant 2015 US$)     NY.ADJ.NNTY.KD
# 1         Adjusted net national income (current US$)     NY.ADJ.NNTY.CD
# 2  Diarrhea treatment (% of children under 5 rece...     SH.STA.ORCF.ZS
# 3  Diarrhea treatment (% of children under 5 who ...        SH.STA.ORTH
# 4  Domestic general government health expenditure...  SH.XPD.GHED.CH.ZS
#
#       2010 [YR2010]     2011 [YR2011]     2012 [YR2012]     2013 [YR2013]  \
# 0   7696500052.9181  9333104170.27045   9233980552.4623  9787444579.97013
# 1  9202620036.57174  11858048667.4025  10946280130.6534  10906792924.9481
# 2                ..                ..                ..                ..
# ...

# %%
#dropping all rows that aren't related to GDP
df = df[df['Series Name'] == 'GDP (current US$)']

output_file_path = 'gdp_data.csv'
df.to_csv(output_file_path, index=False)

# %%
df.head()
# Out:
#     Country Name Country Code        Series Name     Series Code  \
# 7       Botswana          BWA  GDP (current US$)  NY.GDP.MKTP.CD
# 15  Burkina Faso          BFA  GDP (current US$)  NY.GDP.MKTP.CD
# 23       Burundi          BDI  GDP (current US$)  NY.GDP.MKTP.CD
# 31    Cabo Verde          CPV  GDP (current US$)  NY.GDP.MKTP.CD
# 39      Cameroon          CMR  GDP (current US$)  NY.GDP.MKTP.CD
#
#        2010 [YR2010]     2011 [YR2011]     2012 [YR2012]     2013 [YR2013]  \
# 7   12637273429.1339  15110642875.5965  13907464500.1489  14271738366.7917
# 15  10109619736.1442  12080295984.7682  12561015145.3925  13444300489.8634
# 23  2032135191.46211  2235820808.72908  2333341334.45753  2451606631.76696
# 31  1824751459.69304  2046817974.90838  1913081206.32052  2028910915.16446
# 39  27507501809.2414  30630910513.0616  30155062302.8443  33728621190.2114
#
#        2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# ...
